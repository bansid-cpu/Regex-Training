# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
train_data = pd.read_csv('heart.csv') 
test_data = pd.read_csv('o2Saturation.csv')

# %%
train_data.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
test_data.head(10)
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5
# 5  97.5
# 6  97.5
# 7  97.5
# 8  97.5
# 9  97.5

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
train_data.shape
# Out:
# (303, 14)

# %%
test_data.shape
# Out:
# (3585, 1)

# %% [markdown]
# ## Descriptive Statistics

# %%
train_data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
train_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
train_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# 98.6    0
# dtype: int64

# %% [raw]
# There are no missing values present in our data.

# %%
train_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
train_data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
train_data.duplicated().sum()
# Out:
# 1

# %%
train_data.drop_duplicates(inplace = True)

# %%
train_data.shape
# Out:
# (302, 14)

# %% [raw]
# Unique Values

# %%
train_data['caa'].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
train_data['output'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
train_data['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
train_data['oldpeak'].unique()
# Out:
# array([2.3, 3.5, 1.4, 0.8, 0.6, 0.4, 1.3, 0. , 0.5, 1.6, 1.2, 0.2, 1.8,
#        1. , 2.6, 1.5, 3. , 2.4, 0.1, 1.9, 4.2, 1.1, 2. , 0.7, 0.3, 0.9,
#        3.6, 3.1, 3.2, 2.5, 2.2, 2.8, 3.4, 6.2, 4. , 5.6, 2.9, 2.1, 3.8,
#        4.4])

# %% [markdown]
# ## EDA

# %%
figure = plt.figure(figsize=(12,6))
sns.heatmap(train_data.corr(),data = train_data)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x="age",data=train_data);

# %%
sns.countplot(x="sex",hue ='output' ,data=train_data);
plt.xticks(ticks=[0,1],labels=["female","male"])
plt.show()

# %%
tdata=train_data[train_data["output"]==1]
sns.histplot(tdata["thalachh"])
plt.xlabel("MAXIMUM HEART RATE REACHED WHEN OUTPUT 1")
plt.show()

# %%
tdata=train_data[train_data["output"]==0]
sns.histplot(tdata["thalachh"]);
plt.xlabel("MAXIMUM HEART RATE REACHED WHEN OUTPUT 0")
plt.show()

# %%
sns.violinplot(x = 'cp' , y = 'trtbps' , data = train_data)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='trtbps'>

# %%
sns.countplot(x = 'cp' , hue = 'output' , data = train_data)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.barplot(train_data['fbs'],train_data['output'])
# Out:
# C:\Users\sidhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fbs', ylabel='output'>

# %%
sns.stripplot(x="restecg",y="oldpeak",hue="output",data=train_data);

# %%
plt.figure(figsize = (9,5))
sns.histplot(data = train_data, x = "caa", hue = "output") 
plt.title("Distribution of no. of major blodd vessels w.r.t Heart Attack")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="age",y="thalachh",hue="output",data=train_data)
plt.title("EFFECT OF HEART ATTACK WITH INCREASE IN AGE AND MAXIMUM HEART RATE")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="age",y="chol",hue="output",data=train_data)
plt.title("EFFECT OF HEART ATTACK WITH INCREASE IN AGE AND CHOLESTROL")
plt.show()

# %%
train_data.loc[train_data['age']<=20,'age']=0
train_data.loc[(train_data['age']>20 )& (train_data['age']<=40),'age'] =1
train_data.loc[(train_data['age']>40)&(train_data['age']<=60),'age'] =2
train_data.loc[train_data['age']>60,'age'] =3

# %%
sns.set_style('darkgrid')
figure = plt.figure(figsize=(18,8))
sns.barplot(x= 'age', y ='thall',data=train_data,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='age', ylabel='thall'>

# %%
sns.pairplot(train_data[['age','trtbps','chol','thalachh','oldpeak','output']] , hue = 'output')
plt.show()

# %%
train_data.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    3    1   3     145   233    1        0       150     0      2.3    0
# 1    1    1   2     130   250    0        1       187     0      3.5    0
# 2    2    0   1     130   204    0        0       172     0      1.4    2
# 3    2    1   1     120   236    0        1       178     0      0.8    2
# 4    2    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
drop_cols = ['chol','trtbps','oldpeak','thalachh']
train_data = train_data.drop(drop_cols, axis =1)

# %%
train_data.head()
# Out:
#    age  sex  cp  fbs  restecg  exng  slp  caa  thall  output
# 0    3    1   3    1        0     0    0    0      1       1
# 1    1    1   2    0        1     0    0    0      2       1
# 2    2    0   1    0        0     0    2    0      2       1
# 3    2    1   1    0        1     0    2    0      2       1
# 4    2    0   0    0        1     1    2    0      2       1

# %% [markdown]
# ## Linear Regression

# %%
X_train = train_data.drop(['output'],axis =1).values
Y_train = train_data['output'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X_train, Y_train, test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test , y_test)
# Out:
# 0.3113213370738882

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 0.82442561,  0.37674942, -0.07242253,  0.25176043,  0.0024083 ,
#         0.5518816 ,  0.21802405,  0.61818598,  0.16566127,  0.77897191,
#         0.54146078,  0.81779296,  0.65706548,  0.13058836,  0.82512692,
#         0.66964083,  0.65023031,  0.38320033,  0.75544351,  0.98837989,
#         0.00473128,  0.12675957,  0.37140217,  0.69510421,  0.54637264,
#         0.00427316,  0.69694687,  0.4586938 ,  0.91264327,  0.0417909 ,
#         0.42250227,  0.29432222,  0.70902343,  0.97327905,  0.50927239,
#         0.01855159,  0.67403117,  0.00521217,  0.74812744,  0.92656249,
#         0.88717989,  0.46382608,  1.01019462,  0.13225087,  0.50699004,
#         0.29384132,  0.0024083 ,  0.41384228,  0.53137035,  0.54146078,
#         0.70902343,  0.57491858,  0.40740143,  0.34055788,  0.25445872,
#         0.25550117,  0.00487533,  0.16505909,  0.61523805,  0.89930385,
#         0.47247868])

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7704918032786885
